# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzanaeem03/AI-and-Data-Science/blob/Class-Tasks/(883633)_Class_Tasks_Print_statement_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Write a Python program to print your first name and last name on the same line using sep.
print("Muhammad", "Hamza" , sep = " ")
# Out:
# Muhammad Hamza

# %%
# 2. Write a program to print "Python", "Java", and "C++" separated by | using sep.
print("Python" , "Java" , "C++" ,  sep = "|")
# Out:
# Python|Java|C++

# %%
# 3. Write a program to print Day, Month, and Year separated by / using sep.
print("8", "10", "2026", sep = "/")
# Out:
# 8/10/2026

# %%
# 4. Write a program to print your name, age, and city separated by using sep.
print("Muhammad Hamza", "23" ,"Karachi" , sep = " ")
# Out:
# Muhammad Hamza 23 Karachi

# %%
# 5. Write a program to print the numbers 1, 2, 3, 4, 5 separated by , using sep.
print("1", "2" ,"3" ,"4" ,"5" , sep = ",")
# Out:
# 1,2,3,4,5

# %%
# 6. Write a program to print "Hello" and "World" on the same line using end.
print("Hello", end = " ")
print("World", end = " ")
# Out:
# Hello World

# %%
# 7. Write a program that prints "Python" and then prints "Programming" on the same line using end.
print("Python", end = " ")
print("Programming", end = " ")
# Out:
# Python Programming

# %%
# 8. Write a program to print "Welcome", "to", and "Python" on the same line using end.
print("Welcome", end = " ")
print("to", end = " ")
print("Python", end = " ")
# Out:
# Welcome to Python

# %%
# 9. Write a program to print your first name and then your last name on the next line. Use end appropriately.
print("Muhammad")
print("Hamza")
# Out:
# Muhammad
# Muhammad

# %%
# 10. Write a program to print "Loading" followed by three dots using end.
print("Loading", end = "...")
# Out:
# Loading...

# %%
# 11. What will be the output of the following code?



print("A", "B", "C", sep="-")
# Out:
# A-B-C

# %%
# 12. What will be the output of the following code?



print("Hello", end=" ")
print("Python")
# Out:
# Hello Python

# %%
# 13. What will be the output of the following code?



print(1, 2, 3, sep=" | ")
# Out:
# 1 | 2 | 3

# %%
# 14. What will be the output of the following code?



print("Data", end="-")
print("Science")
# Out:
# Data-Science

# %%
# 15. Write a program to display: Python -> Java -> C++ Use sep.

print("Python", "Java", "C++", sep=" -> ")
# Out:
# Python->Java->C++

# %%
# 16. Write a program to display: 10 : 20 : 30 : 40 : 50 using sep.

print("10", "20", "30","40", "50", sep=" : ")
# Out:
# 10 : 20 : 30 : 40 : 50

# %%
# 17. Write a program to display the following on one line: My Name is Ali Use multiple print() statements and end.

print("My", end=" ")
print("Name", end=" ")
print("is", end=" ")
print("Ali", end=" ")
# Out:
# My Name is Ali

# %%
# 18. Write a program to display:

# Python
# is
# easy

# using one print() statement and sep.

print("Python", "is", "easy", sep="\n")
# Out:
# Python
# is
# easy

# %%
# 19. Write a program to display your name, age, and profession in the following format: Name: Ali | Age: 25 | Profession: Student Use sep.

print("Name: Ali", "Age: 25", "Profession: Student", sep=" | ")
# Out:
# Name: Ali | Age: 25 | Profession: Student

# %%
# 20. Write a program that produces the following output using both sep and end:
# Python | Java | C++
# Programming is Fun!

print("Python", "Java", "C++", sep=" | ", end="\n")
print("Programming", "is", "Fun",  "!", sep=" ", end="\n")
# Out:
# Python | Java | C++
# Programming is Fun !
