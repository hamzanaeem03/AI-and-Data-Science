# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzanaeem03/AI-and-Data-Science/blob/Class-Tasks/(883633)_Class_Tasks_Functions_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Class Tasks Without Solutions
#
# ## Task 1 — Personal Information
# Create variables for your name, age, city, and profession. Display all information.
#
# ## Task 2 — Rectangle Calculator
# Create variables for length and width. Calculate area and perimeter.
#
# ## Task 3 — Circle Calculator
# Create a radius variable and use `PI = 3.14159` to calculate the area of a circle.
#
# ## Task 4 — Shopping Calculator
# Create variables for product price and quantity. Calculate the total price.
#
# Example:
# - Price = 250
# - Quantity = 4
#
# ## Task 5 — Temperature Conversion
# Create a Celsius temperature variable and convert it into Fahrenheit.
#
# Formula:
# `Fahrenheit = (Celsius × 9/5) + 32`
#
# ## Task 6 — Student Marks
# Create variables for marks in five subjects. Calculate total and average marks.
#
# ## Task 7 — Salary Calculator
# Create variables for basic salary and bonus. Calculate total salary.
#
# Example:
# - Basic Salary = 50000
# - Bonus = 10000
#
# ## Task 8 — Swap Three Variables
# Create:
# ```python
# a = 10
# b = 20
# c = 30
# ```
# Swap their values so that:
# ```text
# a = 30
# b = 10
# c = 20
# ```
#
# ## Task 9 — User Input
# Take name, age, and city from the user. Store each value in a separate variable and display the information using an f-string.
#
# ## Task 10 — Simple Bill Calculator
# Take product name, product price, and quantity from the user. Calculate and display the product name, price, quantity, and total bill. Convert price and quantity into numeric values.

# %%
# Task 1 — Personal Information
# Create variables for your name, age, city, and profession. Display all information.

name= "Hamza"
age= 23
city= "Karachi"
profession= "Software Engineer"

print("name",name)
print("age",age)
print("city",city)
print("profession",profession)
# Out:
# name Hamza
# age 23
# city Karachi
# profession Software Engineer
