# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzanaeem03/AI-and-Data-Science/blob/Class-Tasks/Class_Tasks_Introduction_to_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a string with your full name and print first and last character.
name = 'Hamza Naeem'
print(name[0])
print(name[-1])
# Out:
# H
# m

# %%
# Apply .strip(), .lower(), .replace() on ' Python is AWESOME '.
text = "Python is AWESOME"
print(text.split())
print(text.lower())
text = text.replace("Python", "javascript")
print(text)
# Out:
# ['Python', 'is', 'AWESOME']
# python is awesome
# javascript is AWESOME

# %%
# Take user input of favorite language and display message.

fav_laguage = input('enter your favorite language')
print(fav_laguage)
# Out:
# enter your favorite language

# %%
# Count how many times 'Python' appears in `'I love Python because Python is powerful'`.
text = 'I love Python because Python is powerful'

print(text.count("Python"))
# Out:
# 2
